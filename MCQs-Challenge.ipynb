# %%
def run_quiz():
    questions = [
        {
            "question": "What is the capital of France?",
            "options": ["A) London", "B) Berlin", "C) Paris", "D) Madrid"],
            "answer": "C"
        },
        {
            "question": "Which planet is known as the Red Planet?",
            "options": ["A) Earth", "B) Mars", "C) Jupiter", "D) Venus"],
            "answer": "B"
        },
        {
            "question": "Who is known as the poet of the nation?",
            "options": ["A) Allama Iqbal", "B) Sir Syed Ahmed Khan", "C) Liaquat Ali Khan", "D) Chaudhry Rehmat Ali"],
            "answer": "A"
        },
        {
            "question": "What is the largest mammal in the world?",
            "options": ["A) Elephant", "B) Blue Whale", "C) Giraffe", "D) Lion"],
            "answer": "B"
        },
        {
            "question": "What is the capital of Pakistan?",
            "options": ["A) Karachi", "B) Lahore", "C) Islamabad", "D) Sukkur"],
            "answer": "C"
        },
        {
            "question": "Which is the largest city of Pakistan?",
            "options": ["A) Islamabad", "B) Lahore", "C) Karachi", "D) Quetta"],
            "answer": "C"
        },
        {
            "question": "What is the currency of Pakistan?",
            "options": ["A) Rupees", "B) Dollar", "C) Euro", "D) Pound"],
            "answer": "A"
        },
        {
            "question": "Which is the largest province of Pakistan?",
            "options": ["A) Sindh", "B) Balochistan", "C) Punjab", "D) KPK"],
            "answer": "B"
        },

    ]

    score = 0

    print("Welcome to the Quiz Game!\n")

    # Loop through each question
    for i, q in enumerate(questions, start=1):
        print(f"Question {i}: {q['question']}")
        for option in q['options']:
            print(option)
        answer = input("Your answer (A/B/C/D): ").strip().upper()
        if answer == q['answer']:
            print("✅ Correct!\n")
            score += 1
        else:
            print(f"❌ Wrong! The correct answer was {q['answer']}\n")

    print(f"Your final score is {score}/{len(questions)}")
    if score == len(questions):
        print("🎉 Excellent! You got them all right!")
    elif score >= len(questions) // 2:
        print("👍 Good job!")
    else:
        print("💡 Keep practicing!")

if __name__ == "__main__":
    run_quiz()
# Out:
# Welcome to the Quiz Game!
#
# Question 1: What is the capital of France?
# A) London
# B) Berlin
# C) Paris
# D) Madrid
# Your answer (A/B/C/D): c
# ✅ Correct!
#
# Question 2: Which planet is known as the Red Planet?
# A) Earth
# B) Mars
# C) Jupiter
# D) Venus
# Your answer (A/B/C/D): b
# ✅ Correct!
#
# Question 3: Who is known as the poet of the nation?
# A) Allama Iqbal
# B) Sir Syed Ahmed Khan
# C) Liaquat Ali Khan
# D) Chaudhry Rehmat Ali
# Your answer (A/B/C/D): a
# ✅ Correct!
#
# Question 4: What is the largest mammal in the world?
# A) Elephant
# B) Blue Whale
# C) Giraffe
# D) Lion
# Your answer (A/B/C/D): a
# ❌ Wrong! The correct answer was B
#
# Question 5: What is the capital of Pakistan?
# A) Karachi
# B) Lahore
# C) Islamabad
# D) Sukkur
# Your answer (A/B/C/D): c
# ✅ Correct!
#
# Question 6: Which is the largest city of Pakistan?
# A) Islamabad
# B) Lahore
# C) Karachi
# D) Quetta
# Your answer (A/B/C/D): c
# ✅ Correct!
#
# ...
